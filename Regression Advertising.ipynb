# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('advertising.csv')

# %% [markdown]
# ## Seperate x and y

# %%
X = df[['TV', 'Radio', 'Newspaper']]
y = df['Sales']

# %% [markdown]
# ## Split the data into training and testing sets

# %%
X_train = X[:-10]  
y_train = y[:-10]
X_test = X[-10:]  
y_test = y[-10:]

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print(y_pred)
# Out:
# [12.45909144  8.35655149  4.37070177 18.48797894 16.48231059  5.28219833
#   8.09289238 12.73951817 23.7842023  15.1380324 ]

# %% [markdown]
# ## Create a figure and axis

# %%
fig, ax = plt.subplots()

ax.plot(range(len(y_test)), y_test, label='Actual Sales')


ax.plot(range(len(y_test)), y_pred, label='Predicted Sales')
